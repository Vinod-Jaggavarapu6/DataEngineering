# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("./apple_products.csv")

# %%
df.head(3)
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# 2  84900                    0               3431                356
#
#                 Upc  Star Rating   Ram
# 0  MOBEXRGV7EHHTGUH          4.6  2 GB
# 1  MOBEXRGVAC6TJT4F          4.6  2 GB
# 2  MOBEXRGVGETABXWZ          4.6  2 GB

# %%
df.count()
# Out:
# Product Name           62
# Product URL            62
# Brand                  62
# Sale Price             62
# Mrp                    62
# Discount Percentage    62
# Number Of Ratings      62
# Number Of Reviews      62
# Upc                    62
# Star Rating            62
# Ram                    62
# dtype: int64

# %%
print(df['Mrp'].max())
# Out:
# 149900

# %%
print(df['Mrp'].min())
# Out:
# 39900

# %%
df[df['Mrp'] == df['Mrp'].max()]
# Out:
#                                   Product Name  \
# 24        APPLE iPhone 12 Pro (Silver, 512 GB)
# 41  APPLE iPhone 12 Pro (Pacific Blue, 512 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 24  https://www.flipkart.com/apple-iphone-12-pro-s...  Apple      140900
# 41  https://www.flipkart.com/apple-iphone-12-pro-p...  Apple      140900
#
#        Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 24  149900                    6                542                 42
# 41  149900                    6                545                 42
#
#                  Upc  Star Rating   Ram
# 24  MOBFWBYZ5UY6ZBVA          4.5  4 GB
# 41  MOBFWBYZTHSXKMGW          4.5  4 GB

# %%
df[df['Mrp']== df['Mrp'].min()]
# Out:
#                       Product Name  \
# 52  APPLE iPhone SE (White, 64 GB)
# 57  APPLE iPhone SE (Black, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 52  39900                   24              95807               8154
# 57  39900                   24              95909               8161
#
#                  Upc  Star Rating   Ram
# 52  MOBFWQ6BGWDVGF3E          4.5  2 GB
# 57  MOBFWQ6BR3MK7AUG          4.5  4 GB

# %%
priced_df = df[df['Mrp']>=100000]
priced_df
# Out:
#                                         Product Name  \
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 18       APPLE iPhone 11 Pro (Midnight Green, 64 GB)
# 19          APPLE iPhone 11 Pro (Space Grey, 512 GB)
# 20   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 21      APPLE iPhone 11 Pro (Midnight Green, 512 GB)
# 22          APPLE iPhone 11 Pro (Space Grey, 256 GB)
# 24              APPLE iPhone 12 Pro (Silver, 512 GB)
# 25    APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)
# 27            APPLE iPhone 12 Pro (Graphite, 256 GB)
# 30            APPLE iPhone 12 Pro (Graphite, 128 GB)
# 31        APPLE iPhone 12 Pro Max (Graphite, 256 GB)
# 32        APPLE iPhone 12 Pro Max (Graphite, 128 GB)
# 37          APPLE iPhone 12 Pro Max (Silver, 128 GB)
# 39            APPLE iPhone 12 Pro Max (Gold, 128 GB)
# ...

# %%
priced_df.count()
# Out:
# Product Name           22
# Product URL            22
# Brand                  22
# Sale Price             22
# Mrp                    22
# Discount Percentage    22
# Number Of Ratings      22
# Number Of Reviews      22
# Upc                    22
# Star Rating            22
# Ram                    22
# dtype: int64

# %%
list(df['Product Name'])[0].upper()
# Out:
# 'APPLE IPHONE 8 PLUS (GOLD, 64 GB)'

# %%
list(df['Product Name'])[0].lower()
# Out:
# 'apple iphone 8 plus (gold, 64 gb)'

# %%
productNames = list(df['Product Name'])
print(productNames)
# Out:
# ['APPLE iPhone 8 Plus (Gold, 64 GB)', 'APPLE iPhone 8 Plus (Space Grey, 256 GB)', 'APPLE iPhone 8 Plus (Silver, 256 GB)', 'APPLE iPhone 8 (Silver, 256 GB)', 'APPLE iPhone 8 (Gold, 256 GB)', 'APPLE iPhone 8 Plus (Silver, 64 GB)', 'APPLE iPhone 8 Plus (Space Grey, 64 GB)', 'APPLE iPhone 8 (Space Grey, 256 GB)', 'APPLE iPhone XS Max (Silver, 64 GB)', 'Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includes EarPods, Power Adapter)', 'Apple iPhone XR (Black, 64 GB) (Includes EarPods, Power Adapter)', 'Apple iPhone XR (Coral, 128 GB) (Includes EarPods, Power Adapter)', 'Apple iPhone XR (Black, 128 GB) (Includes EarPods, Power Adapter)', 'Apple iPhone XR (White, 128 GB) (Includes EarPods, Power Adapter)', 'APPLE iPhone 11 Pro Max (Gold, 256 GB)', 'APPLE iPhone 11 Pro Max (Gold, 64 GB)', 'APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)', 'APPLE iPhone 11 Pro Max (Space Grey, 64 GB)', 'APPLE iPhone 11 Pro (Midnight Green, 64 GB)', 'APPLE iPhone 11 Pro (Space Grey, 512 GB)', 'APPLE iPhone 11 Pro Max
# ...

# %%
modelNames = [pname[6:15].upper().strip() for pname in productNames]
print(modelNames)
# Out:
# ['IPHONE 8', 'IPHONE 8', 'IPHONE 8', 'IPHONE 8', 'IPHONE 8', 'IPHONE 8', 'IPHONE 8', 'IPHONE 8', 'IPHONE XS', 'IPHONE XR', 'IPHONE XR', 'IPHONE XR', 'IPHONE XR', 'IPHONE XR', 'IPHONE 11', 'IPHONE 11', 'IPHONE 11', 'IPHONE 11', 'IPHONE 11', 'IPHONE 11', 'IPHONE 11', 'IPHONE 11', 'IPHONE 11', 'IPHONE SE', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 12', 'IPHONE 11', 'IPHONE 11', 'IPHONE SE', 'IPHONE SE', 'IPHONE SE', 'IPHONE SE', 'IPHONE 11', 'IPHONE SE', 'IPHONE 11', 'IPHONE 11', 'IPHONE 11', 'IPHONE 11']

# %%
df['Model Name'] = modelNames

# %%
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
list(df['Product Name'])[51][6:15].upper().strip()
# Out:
# 'IPHONE 11'

# %%
df['Model Name'] = df['Product Name'].str[6:15]

# %%
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
df.tail()
# Out:
#                        Product Name  \
# 57   APPLE iPhone SE (Black, 64 GB)
# 58  APPLE iPhone 11 (Purple, 64 GB)
# 59   APPLE iPhone 11 (White, 64 GB)
# 60   APPLE iPhone 11 (Black, 64 GB)
# 61     APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       46999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       46999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       46999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       46999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 57  39900                   24              95909               8161
# 58  54900                   14              43470               3331
# 59  54900                   14              43470               3331
# ...

# %%
df.sort_values(by='Discount Percentage', na_position='first', ascending = False, inplace = True)
df
# Out:
#                                    Product Name  \
# 18  APPLE iPhone 11 Pro (Midnight Green, 64 GB)
# 52               APPLE iPhone SE (White, 64 GB)
# 57               APPLE iPhone SE (Black, 64 GB)
# 55                APPLE iPhone SE (Red, 128 GB)
# 54              APPLE iPhone SE (White, 128 GB)
# ..                                          ...
# 3               APPLE iPhone 8 (Silver, 256 GB)
# 2          APPLE iPhone 8 Plus (Silver, 256 GB)
# 7           APPLE iPhone 8 (Space Grey, 256 GB)
# 15        APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 0             APPLE iPhone 8 Plus (Gold, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 18  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple       74999
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 55  https://www.flipkart.com/apple-iphone-se-red-1...  Apple       34999
# ...
